# %% [markdown]
# # recipe preprocessing

# %%
import pandas as pd, json, re, unicodedata, ast, math, os
from fractions import Fraction
from datetime import datetime, timezone
from tqdm.auto import tqdm

# %%
# === Helpers (one cell) =======================================================
import re, math, ast, unicodedata
from datetime import datetime, timezone
from fractions import Fraction

# --- Constants ----------------------------------------------------------------
UNITS   = {"tsp","teaspoon","tbsp","tablespoon","cup","cups","g","kg","ml","l","pound","lb","oz"}
ANIMAL  = {"beef","chicken","pork","lamb","shrimp","prawn","fish","tuna","salmon","anchovy","egg","milk","butter","cheese","yogurt","honey"}
GLUTEN  = {"wheat","flour","breadcrumbs","barley","rye","semolina","farina","spelt","bulgur","seitan","graham"}
FLAVOUR_KEYWORDS = {
    "spicy": {"chili","chile","jalapeno","harissa","gochugaru","sriracha","cayenne","chilli"},
    "smoky": {"smoked","chipotle","smoky"},
    "sweet": {"sugar","honey","maple","syrup","molasses"},
    "herby": {"basil","parsley","cilantro","dill","oregano","thyme","rosemary","mint","sage"},
    "tangy": {"lemon","lime","vinegar","sumac","tamarind","yogurt"},
    "umami": {"miso","soy","tamari","anchovy","mushroom","kombu","parmesan"}
}

# --- General utilities --------------------------------------------------------
def now_mongo_date():
    return {"$date": datetime.now(timezone.utc).isoformat().replace("+00:00","Z")}

def norm(s) -> str:
    # make sure we never pass None/NaN to unicodedata.normalize
    s = safe_str(s)
    s = unicodedata.normalize("NFKC", s).strip()
    return re.sub(r"\s+", " ", s).lower()


def slugify(s: str) -> str:
    return re.sub(r"[^a-z0-9]+", "-", norm(s)).strip("-")

def safe_str(x):
    """Return '' for None/NaN; else str(x)."""
    if x is None:
        return ""
    if isinstance(x, float) and math.isnan(x):
        return ""
    return str(x)

def safe_join(parts):
    """Join after converting each part to safe_str and dropping empties."""
    parts = [safe_str(p) for p in parts]
    return " ".join(p for p in parts if p)

# --- Parsing & tagging --------------------------------------------------------
def to_number(qs: str):
    qs = (qs or "").strip()
    if not qs: 
        return None
    try:
        if " " in qs:            # mixed number e.g., "1 1/2"
            a, b = qs.split(" ", 1)
            return float(Fraction(a) + Fraction(b))
        if "/" in qs:            # fraction e.g., "1/2"
            return float(Fraction(qs))
        return float(qs)
    except Exception:
        return None

def parse_ingredient(raw: str):
    t = norm(raw)
    # qty + unit + name (naive but solid starting point)
    m = re.match(r"^([\d\s\/\.]+)\s*([a-zA-Z]+)?\s*(.*)$", t)
    qty, unit, rest = None, None, t
    if m:
        qty_s, unit_s, rest = m.groups()
        qty = to_number(qty_s) if qty_s else None
        if unit_s and unit_s.lower() in UNITS:
            unit = unit_s.lower()
        else:
            rest = ((unit_s or "") + " " + rest).strip() if unit_s else rest
    name = rest.strip(", ")
    return {"name": name, "qty": qty, "unit": unit, "raw": raw}

def derive_dietary(ingredient_names):
    names = set(ingredient_names)
    vegan = not any(x in names for x in ANIMAL)
    vegetarian = not any(x in names for x in {"beef","chicken","pork","lamb","shrimp","prawn","fish","tuna","salmon","anchovy"})
    gf = not any(x in names for x in GLUTEN)
    tags = []
    if vegan:
        tags.append("vegan")
    elif vegetarian:
        tags.append("vegetarian")
    if gf:
        tags.append("gluten-free")
    return tags

def derive_flavour_keyword(all_text: str):
    t = norm(all_text)
    tags = []
    for label, keys in FLAVOUR_KEYWORDS.items():
        if any(k in t for k in keys):
            tags.append(label)
    return sorted(set(tags))

def to_list_from_cell(x):
    """
    Parse list-like strings safely. Always returns List[str] with NaNs removed.
    Accepts forms like "[""foo"", ""bar""]", or falls back to line/pipe split.
    """
    if x is None or (isinstance(x, float) and math.isnan(x)):
        return []
    s = safe_str(x).strip()
    try:
        v = ast.literal_eval(s)
        if isinstance(v, (list, tuple)):
            return [safe_str(i) for i in v if safe_str(i)]
        return [safe_str(v)] if safe_str(v) else []
    except Exception:
        if "|" in s:
            return [p.strip() for p in s.split("|") if p.strip()]
        if "\n" in s:
            return [p.strip() for p in s.split("\n") if p.strip()]
        return [s] if s else []

# %% [markdown]
# ## load dataset from data folder

# %%
from pathlib import Path
import os, glob
print("CWD:", os.getcwd())  

CSV_PATH = Path("data") / "recipe_nlg" / "full_dataset.csv"   
print("CSV exists?", CSV_PATH.exists(), "→", CSV_PATH)
# Out:
# CWD: /Users/Lorena/Developer/FlavorNet/mongoDB
# CSV exists? True → data/recipe_nlg/full_dataset.csv

# %%
import pandas as pd

df = pd.read_csv(
    CSV_PATH,
    usecols=["title","ingredients","directions","link","source","NER"],
    low_memory=False  
)

# %%
df.shape
# Out:
# (2231142, 6)

# %%
df.head()
# Out:
#                    title                                        ingredients  \
# 0    No-Bake Nut Cookies  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  Jewell Ball'S Chicken  ["1 small jar chipped beef, cut up", "4 boned ...
# 2            Creamy Corn  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3          Chicken Funny  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4   Reeses Cups(Candy)    ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                           directions  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
#
#                                                  NER
# 0  ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1  ["beef", "chicken breasts", "cream of mushroom...
# 2  ["frozen corn", "cream cheese", "butter", "gar...
# 3  ["chicken", "chicken gravy", "cream of mushroo...
# 4  ["peanut butter", "graham cracker crumbs", "bu...

# %% [markdown]
# ### Original columns in `full_dataset.csv`
#
# Inlcuded in **RecipeNLG** dataset:
#
# | column | meaning |
# |--------|----------|
# | `title` | the recipe’s name (e.g., “No-Bake Nut Cookies”) |
# | `ingredients` | list-like string of raw ingredient phrases (e.g., `["1 c. sugar", "1/2 c. milk", ...]`) |
# | `directions` | list-like string of recipe steps |
# | `link` | original web source URL |
# | `source` | scraped website or author |
# | `NER` | list of named entities / ingredient names extracted by NLP |
#
# ---
#
# ### Our preprocessing / augmentation
#
#
# | new field | how it was produced | example |
# |------------|--------------------|----------|
# | `ingredients (parsed)` | converted each text ingredient into `{name, qty, unit, raw}` via `parse_ingredient()` | `{"name": "sugar", "qty": 1.0, "unit": "cup", ...}` |
# | `ingredient_tags` | merged `NER` entities + parsed ingredient names → normalized lowercase unique list | `["sugar", "milk", "nuts", ...]` |
# | `dietary_tags` | added by preprocessing (`derive_dietary()`): rule-based detection of vegan / vegetarian / gluten-free from `ingredient_tags` | `["vegetarian", "gluten-free"]` |
# | `flavour_tags` | added by preprocessing (`derive_flavour_keyword()`): keyword matching on ingredients + directions for flavour profiles | `["sweet"]`, `["umami"]`, etc. |
# | `slug` | generated URL-safe version of the title (`slugify()`) | `"no-bake-nut-cookies"` |
# | `created_at`, `updated_at` | timestamps for Mongo | ISODate values |
# | `times`, `nutrition`, `rating`, `images` | empty placeholders for schema compatibility | — |
#
# ---
#
# ### table  (`dietary`, `flavour`, `n_ings`)
#
# - **`dietary`** → built by rule-based `derive_dietary()` function.
# - **`flavour`** → built by keyword `derive_flavour_keyword()` function.
# - **`n_ings`** → simple count of `len(d["ingredients"])` (sanity-check parsing).

# %% [markdown]
# ## transform to mongo schema

# %%
out_docs = []

for _, row in tqdm(df.iterrows(), total=len(df)):
    title = safe_str(row.get("title"))
    ing_raw = to_list_from_cell(row.get("ingredients"))
    steps   = to_list_from_cell(row.get("directions"))
    ner     = to_list_from_cell(row.get("NER"))
    
    ings = [parse_ingredient(x) for x in ing_raw]
    ner_tags = [norm(x) for x in ner if x]
    parsed_tags = [norm(i["name"]) for i in ings if i["name"]]
    ingredient_tags = sorted(set([t for t in ner_tags if t] + parsed_tags))
    
    dietary = derive_dietary(ingredient_tags)
    flavour = derive_flavour_keyword(safe_join([title] + ing_raw + steps))



    doc = {
        "title": title,
        "slug": slugify(title),
        "ingredients": ings,
        "steps": steps,
        "tags": [],
        "dietary_tags": dietary,
        "flavour_tags": flavour,
        "ingredient_tags": ingredient_tags,
        "cuisine": None,
        "course": None,
        "servings": None,
        "times": {"prep_min": None, "cook_min": None, "total_min": None},
        "nutrition": {},
        "rating": {"value": None, "count": None},
        "images": [],
        "source_url": row.get("link"),
        "author": row.get("source"),
        "created_at": now_mongo_date(),
        "updated_at": now_mongo_date()
    }
    out_docs.append(doc)

len(out_docs)
# Out:
#   0%|          | 0/2231142 [00:00<?, ?it/s]
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/Users/Lorena/.local/share/uv/python/cpython-3.12.11-macos-aarch64-none/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/Users/Lorena/Developer/FlavorNet/.venv/lib/python3.12/site-packages/tqdm/_monitor.py", line 84, in run
#     instance.refresh(nolock=True)
#   File "/Users/Lorena/Developer/FlavorNet/.venv/lib/python3.12/site-packages/tqdm/std.py", line 1347, in refresh
#     self.display()
#   File "/Users/Lorena/Developer/FlavorNet/.venv/lib/python3.12/site-packages/tqdm/notebook.py", line 171, in display
#     rtext.value = right
#     ^^^^^^^^^^^
#   File "/Users/Lorena/Developer/FlavorNet/.venv/lib/python3.12/site-packages/traitlets/traitlets.py", line 716, in __set__
#     self.set(obj, value)
#   File "/Users/Lorena/Developer/FlavorNet/.venv/lib/python3.12/site-packages/traitlets/traitlets.py", line 706, in set
#     obj._notify_trait(self.name, old_value, new_value)
#   File "/Users/Lorena/Developer/FlavorNet/.venv/lib/python3.12/site-packages/traitlets/traitlets.py", line 1513, in _notify_trait
#     self.notify_change(
#   File "/Users/Lorena/Developer/FlavorNet/.venv/lib/python3.12/site-packages/ipywidgets/widgets/widget.py", line 700, in notify_change
#     self.send_state(key=name)
#   File "/Users/Lorena/Developer/FlavorNet/.venv/lib/python3.12/site-packages/ipywidgets/widgets/widget.py", line 586, in send_state
#     self._send(msg, buffers=buffers)
#   File "/Users/Lorena/Developer/FlavorNet/.venv/lib/python3.12/site-packages/ipywidgets/widgets/widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#   File "/Users/Lorena/Developer/FlavorNet/.venv/lib/python3.12/site-packages/comm/base_comm.py", line 144, in send
#     self.publish_msg(
#   File "/Users/Lorena/Developer/FlavorNet/.venv/lib/python3.12/site-packages/ipykernel/comm/comm.py", line 42, in publish_msg
#     parent=self.kernel.get_parent(),
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/Lorena/Developer/FlavorNet/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 797, in get_parent
#     return self._shell_parent.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^
# LookupError: <ContextVar name='shell_parent' at 0x105003740>
# 2231142

# %%
out_docs
# Out:
# [{'title': 'No-Bake Nut Cookies',
#   'slug': 'no-bake-nut-cookies',
#   'ingredients': [{'name': 'c . firmly packed brown sugar',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. firmly packed brown sugar'},
#    {'name': 'c . evaporated milk',
#     'qty': 0.5,
#     'unit': None,
#     'raw': '1/2 c. evaporated milk'},
#    {'name': '. vanilla', 'qty': 0.5, 'unit': 'tsp', 'raw': '1/2 tsp. vanilla'},
#    {'name': 'c . broken nuts (pecans)',
#     'qty': 0.5,
#     'unit': None,
#     'raw': '1/2 c. broken nuts (pecans)'},
#    {'name': '. butter or margarine',
#     'qty': 2.0,
#     'unit': 'tbsp',
#     'raw': '2 Tbsp. butter or margarine'},
#    {'name': 'c . bite size shredded rice biscuits',
#     'qty': 3.5,
#     'unit': None,
#     'raw': '3 1/2 c. bite size shredded rice biscuits'}],
#   'steps': ['In a heavy 2-quart saucepan, mix brown sugar, nuts, evaporated milk and butter or margarine.',
#    'Stir over medium heat until mixture bubbles all over top.',
#    'Boil and stir 5 minutes more. Take off heat.',
#    'Stir in vanilla and cereal; mix well.',
#    'Using 2 teaspoons, drop and shape into 30 clusters on wax paper.',
#    'Let stand until firm, about 30 minutes.'],
#   'tags': [],
#   'dietary_tags': ['vegetarian', 'gluten-free'],
#   'flavour_tags': ['sweet'],
#   'ingredient_tags': ['. butter or margarine',
#    '. vanilla',
#    'bite size shredded rice biscuits',
#    'brown sugar',
#    'butter',
#    'c . bite size shredded rice biscuits',
#    'c . broken nuts (pecans)',
#    'c . evaporated milk',
#    'c . firmly packed brown sugar',
#    'milk',
#    'nuts',
#    'vanilla'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=44874',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.882190Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.882195Z'}},
#  {'title': "Jewell Ball'S Chicken",
#   'slug': 'jewell-ball-s-chicken',
#   'ingredients': [{'name': 'small jar chipped beef, cut up',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 small jar chipped beef, cut up'},
#    {'name': 'boned chicken breasts',
#     'qty': 4.0,
#     'unit': None,
#     'raw': '4 boned chicken breasts'},
#    {'name': 'can cream of mushroom soup',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 can cream of mushroom soup'},
#    {'name': 'carton sour cream',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 carton sour cream'}],
#   'steps': ['Place chipped beef on bottom of baking dish.',
#    'Place chicken on top of beef.',
#    'Mix soup and cream together; pour over chicken. Bake, uncovered, at 275° for 3 hours.'],
#   'tags': [],
#   'dietary_tags': ['gluten-free'],
#   'flavour_tags': ['umami'],
#   'ingredient_tags': ['beef',
#    'boned chicken breasts',
#    'can cream of mushroom soup',
#    'carton sour cream',
#    'chicken breasts',
#    'cream of mushroom soup',
#    'small jar chipped beef, cut up',
#    'sour cream'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=699419',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.882685Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.882692Z'}},
#  {'title': 'Creamy Corn',
#   'slug': 'creamy-corn',
#   'ingredients': [{'name': '(16 oz.) pkg. frozen corn',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2 (16 oz.) pkg. frozen corn'},
#    {'name': '(8 oz.) pkg. cream cheese, cubed',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 (8 oz.) pkg. cream cheese, cubed'},
#    {'name': 'c . butter, cubed',
#     'qty': 0.3333333333333333,
#     'unit': None,
#     'raw': '1/3 c. butter, cubed'},
#    {'name': '. garlic powder',
#     'qty': 0.5,
#     'unit': 'tsp',
#     'raw': '1/2 tsp. garlic powder'},
#    {'name': '. salt', 'qty': 0.5, 'unit': 'tsp', 'raw': '1/2 tsp. salt'},
#    {'name': '. pepper', 'qty': 0.25, 'unit': 'tsp', 'raw': '1/4 tsp. pepper'}],
#   'steps': ['In a slow cooker, combine all ingredients. Cover and cook on low for 4 hours or until heated through and cheese is melted. Stir well before serving. Yields 6 servings.'],
#   'tags': [],
#   'dietary_tags': ['vegetarian', 'gluten-free'],
#   'flavour_tags': [],
#   'ingredient_tags': ['(16 oz.) pkg. frozen corn',
#    '(8 oz.) pkg. cream cheese, cubed',
#    '. garlic powder',
#    '. pepper',
#    '. salt',
#    'butter',
#    'c . butter, cubed',
#    'cream cheese',
#    'frozen corn',
#    'garlic powder',
#    'pepper',
#    'salt'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=10570',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.882983Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.882987Z'}},
#  {'title': 'Chicken Funny',
#   'slug': 'chicken-funny',
#   'ingredients': [{'name': 'large whole chicken',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 large whole chicken'},
#    {'name': '(10 1/2 oz.) cans chicken gravy',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2 (10 1/2 oz.) cans chicken gravy'},
#    {'name': '(10 1/2 oz.) can cream of mushroom soup',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 (10 1/2 oz.) can cream of mushroom soup'},
#    {'name': '(6 oz.) box stove top stuffing',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 (6 oz.) box Stove Top stuffing'},
#    {'name': '. shredded cheese',
#     'qty': 4.0,
#     'unit': 'oz',
#     'raw': '4 oz. shredded cheese'}],
#   'steps': ['Boil and debone chicken.',
#    'Put bite size pieces in average size square casserole dish.',
#    'Pour gravy and cream of mushroom soup over chicken; level.',
#    'Make stuffing according to instructions on box (do not make too moist).',
#    'Put stuffing on top of chicken and gravy; level.',
#    'Sprinkle shredded cheese on top and bake at 350° for approximately 20 minutes or until golden and bubbly.'],
#   'tags': [],
#   'dietary_tags': ['gluten-free'],
#   'flavour_tags': ['umami'],
#   'ingredient_tags': ['(10 1/2 oz.) can cream of mushroom soup',
#    '(10 1/2 oz.) cans chicken gravy',
#    '(6 oz.) box stove top stuffing',
#    '. shredded cheese',
#    'chicken',
#    'chicken gravy',
#    'cream of mushroom soup',
#    'large whole chicken',
#    'shredded cheese'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=897570',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.883254Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.883258Z'}},
#  {'title': 'Reeses Cups(Candy)  ',
#   'slug': 'reeses-cups-candy',
#   'ingredients': [{'name': 'c . peanut butter',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. peanut butter'},
#    {'name': 'c . graham cracker crumbs',
#     'qty': 0.75,
#     'unit': None,
#     'raw': '3/4 c. graham cracker crumbs'},
#    {'name': 'c . melted butter',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. melted butter'},
#    {'name': '. (3 1/2 c.) powdered sugar',
#     'qty': 1.0,
#     'unit': 'lb',
#     'raw': '1 lb. (3 1/2 c.) powdered sugar'},
#    {'name': 'large pkg. chocolate chips',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 large pkg. chocolate chips'}],
#   'steps': ['Combine first four ingredients and press in 13 x 9-inch ungreased pan.',
#    'Melt chocolate chips and spread over mixture. Refrigerate for about 20 minutes and cut into pieces before chocolate gets hard.',
#    'Keep in refrigerator.'],
#   'tags': [],
#   'dietary_tags': ['vegetarian', 'gluten-free'],
#   'flavour_tags': ['sweet'],
#   'ingredient_tags': ['. (3 1/2 c.) powdered sugar',
#    'butter',
#    'c . graham cracker crumbs',
#    'c . melted butter',
#    'c . peanut butter',
#    'chocolate chips',
#    'graham cracker crumbs',
#    'large pkg. chocolate chips',
#    'peanut butter',
#    'powdered sugar'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=659239',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.883477Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.883479Z'}},
#  {'title': 'Cheeseburger Potato Soup',
#   'slug': 'cheeseburger-potato-soup',
#   'ingredients': [{'name': 'baking potatoes',
#     'qty': 6.0,
#     'unit': None,
#     'raw': '6 baking potatoes'},
#    {'name': '. of extra lean ground beef',
#     'qty': 1.0,
#     'unit': 'lb',
#     'raw': '1 lb. of extra lean ground beef'},
#    {'name': 'c . butter or margarine',
#     'qty': 0.6666666666666666,
#     'unit': None,
#     'raw': '2/3 c. butter or margarine'},
#    {'name': 'c . milk', 'qty': 6.0, 'unit': None, 'raw': '6 c. milk'},
#    {'name': '. salt', 'qty': 0.75, 'unit': 'tsp', 'raw': '3/4 tsp. salt'},
#    {'name': '. pepper', 'qty': 0.5, 'unit': 'tsp', 'raw': '1/2 tsp. pepper'},
#    {'name': 'c (6 oz.) shredded cheddar cheese, divided',
#     'qty': 1.5,
#     'unit': None,
#     'raw': '1 1/2 c (6 oz.) shredded Cheddar cheese, divided'},
#    {'name': 'sliced bacon, cooked, crumbled and divided',
#     'qty': 12.0,
#     'unit': None,
#     'raw': '12 sliced bacon, cooked, crumbled and divided'},
#    {'name': 'green onion, chopped and divided',
#     'qty': 4.0,
#     'unit': None,
#     'raw': '4 green onion, chopped and divided'},
#    {'name': '(8 oz.) carton sour cream (optional)',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 (8 oz.) carton sour cream (optional)'}],
#   'steps': ['Wash potatoes; prick several times with a fork.',
#    'Microwave them with a wet paper towel covering the potatoes on high for 6-8 minutes.',
#    'The potatoes should be soft, ready to eat.',
#    'Let them cool enough to handle.',
#    'Cut in half lengthwise; scoop out pulp and reserve.',
#    'Discard shells.',
#    'Brown ground beef until done.',
#    'Drain any grease from the meat.',
#    'Set aside when done.',
#    'Meat will be added later.',
#    'Melt butter in a large kettle over low heat; add flour, stirring until smooth.',
#    'Cook 1 minute, stirring constantly. Gradually add milk; cook over medium heat, stirring constantly, until thickened and bubbly.',
#    'Stir in potato, ground beef, salt, pepper, 1 cup of cheese, 2 tablespoons of green onion and 1/2 cup of bacon.',
#    'Cook until heated (do not boil).',
#    'Stir in sour cream if desired; cook until heated (do not boil).',
#    'Sprinkle with remaining cheese, bacon and green onions.'],
#   'tags': [],
#   'dietary_tags': ['vegetarian', 'gluten-free'],
#   'flavour_tags': [],
#   'ingredient_tags': ['(8 oz.) carton sour cream (optional)',
#    '. of extra lean ground beef',
#    '. pepper',
#    '. salt',
#    'bacon',
#    'baking potatoes',
#    'butter',
#    'c (6 oz.) shredded cheddar cheese, divided',
#    'c . butter or margarine',
#    'c . milk',
#    'cheddar cheese',
#    'extra lean ground beef',
#    'green onion',
#    'green onion, chopped and divided',
#    'milk',
#    'pepper',
#    'salt',
#    'sliced bacon, cooked, crumbled and divided',
#    'sour cream'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=20115',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.883878Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.883882Z'}},
#  {'title': 'Rhubarb Coffee Cake',
#   'slug': 'rhubarb-coffee-cake',
#   'ingredients': [{'name': 'c . sugar',
#     'qty': 1.5,
#     'unit': None,
#     'raw': '1 1/2 c. sugar'},
#    {'name': 'c . butter', 'qty': 0.5, 'unit': None, 'raw': '1/2 c. butter'},
#    {'name': 'egg', 'qty': 1.0, 'unit': None, 'raw': '1 egg'},
#    {'name': 'c . buttermilk',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. buttermilk'},
#    {'name': 'c . flour', 'qty': 2.0, 'unit': None, 'raw': '2 c. flour'},
#    {'name': '. salt', 'qty': 0.5, 'unit': 'tsp', 'raw': '1/2 tsp. salt'},
#    {'name': '. soda', 'qty': 1.0, 'unit': 'tsp', 'raw': '1 tsp. soda'},
#    {'name': 'c . buttermilk',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. buttermilk'},
#    {'name': 'c . rhubarb, finely cut',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2 c. rhubarb, finely cut'},
#    {'name': '. vanilla', 'qty': 1.0, 'unit': 'tsp', 'raw': '1 tsp. vanilla'}],
#   'steps': ['Cream sugar and butter.',
#    'Add egg and beat well.',
#    'To creamed butter, sugar and egg, add alternately buttermilk with mixture of flour, salt and soda.',
#    'Mix well.',
#    'Add rhubarb and vanilla.',
#    'Pour into greased 9 x 13-inch pan and add Topping.'],
#   'tags': [],
#   'dietary_tags': ['vegetarian'],
#   'flavour_tags': ['sweet'],
#   'ingredient_tags': ['. salt',
#    '. soda',
#    '. vanilla',
#    'butter',
#    'buttermilk',
#    'c . butter',
#    'c . buttermilk',
#    'c . flour',
#    'c . rhubarb, finely cut',
#    'c . sugar',
#    'egg',
#    'flour',
#    'rhubarb',
#    'salt',
#    'soda',
#    'sugar',
#    'vanilla'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=210288',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.884121Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.884124Z'}},
#  {'title': 'Scalloped Corn',
#   'slug': 'scalloped-corn',
#   'ingredients': [{'name': 'can cream-style corn',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 can cream-style corn'},
#    {'name': 'can whole kernel corn',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 can whole kernel corn'},
#    {'name': 'pkg . (approximately 20) saltine crackers, crushed',
#     'qty': 0.5,
#     'unit': None,
#     'raw': '1/2 pkg. (approximately 20) saltine crackers, crushed'},
#    {'name': 'egg , beaten', 'qty': 1.0, 'unit': None, 'raw': '1 egg, beaten'},
#    {'name': '. butter, divided',
#     'qty': 6.0,
#     'unit': 'tsp',
#     'raw': '6 tsp. butter, divided'},
#    {'name': 'pepper to taste',
#     'qty': None,
#     'unit': None,
#     'raw': 'pepper to taste'}],
#   'steps': ['Mix together both cans of corn, crackers, egg, 2 teaspoons of melted butter and pepper and place in a buttered baking dish.',
#    'Dot with remaining 4 teaspoons of butter.',
#    'Bake at 350° for 1 hour.'],
#   'tags': [],
#   'dietary_tags': ['vegetarian', 'gluten-free'],
#   'flavour_tags': [],
#   'ingredient_tags': ['. butter, divided',
#    'butter',
#    'can cream-style corn',
#    'can whole kernel corn',
#    'crackers',
#    'cream-style corn',
#    'egg',
#    'egg , beaten',
#    'pepper',
#    'pepper to taste',
#    'pkg . (approximately 20) saltine crackers, crushed',
#    'whole kernel corn'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=876969',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.884296Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.884298Z'}},
#  {'title': "Nolan'S Pepper Steak",
#   'slug': 'nolan-s-pepper-steak',
#   'ingredients': [{'name': '. round steak (1-inch thick), cut into strips',
#     'qty': 1.5,
#     'unit': 'lb',
#     'raw': '1 1/2 lb. round steak (1-inch thick), cut into strips'},
#    {'name': 'can drained tomatoes, cut up (save liquid)',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 can drained tomatoes, cut up (save liquid)'},
#    {'name': 'c . water', 'qty': 1.75, 'unit': None, 'raw': '1 3/4 c. water'},
#    {'name': 'c . onions', 'qty': 0.5, 'unit': None, 'raw': '1/2 c. onions'},
#    {'name': '. worcestershire sauce',
#     'qty': 1.5,
#     'unit': 'tbsp',
#     'raw': '1 1/2 Tbsp. Worcestershire sauce'},
#    {'name': 'green peppers, diced',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2 green peppers, diced'},
#    {'name': 'c . oil', 'qty': 0.25, 'unit': None, 'raw': '1/4 c. oil'}],
#   'steps': ['Roll steak strips in flour.',
#    'Brown in skillet.',
#    'Salt and pepper.',
#    'Combine tomato liquid, water, onions and browned steak. Cover and simmer for one and a quarter hours.',
#    'Uncover and stir in Worcestershire sauce.',
#    'Add tomatoes, green peppers and simmer for 5 minutes.',
#    'Serve over hot cooked rice.'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': [],
#   'ingredient_tags': ['. round steak (1-inch thick), cut into strips',
#    '. worcestershire sauce',
#    'c . oil',
#    'c . onions',
#    'c . water',
#    'can drained tomatoes, cut up (save liquid)',
#    'green peppers',
#    'green peppers, diced',
#    'oil',
#    'onions',
#    'tomatoes',
#    'water',
#    'worcestershire sauce'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=375254',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.884488Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.884490Z'}},
#  {'title': 'Millionaire Pie',
#   'slug': 'millionaire-pie',
#   'ingredients': [{'name': 'large container cool whip',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 large container Cool Whip'},
#    {'name': 'large can crushed pineapple',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 large can crushed pineapple'},
#    {'name': 'can condensed milk',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 can condensed milk'},
#    {'name': 'lemons', 'qty': 3.0, 'unit': None, 'raw': '3 lemons'},
#    {'name': 'c . pecans', 'qty': 1.0, 'unit': None, 'raw': '1 c. pecans'},
#    {'name': 'graham cracker crusts',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2 graham cracker crusts'}],
#   'steps': ['Empty Cool Whip into a bowl.',
#    'Drain juice from pineapple.',
#    'Mix Cool Whip and pineapple.',
#    'Add condensed milk.',
#    'Squeeze lemons, remove seeds and add to Cool Whip and pineapple.',
#    'Chop nuts into small pieces and add to mixture.',
#    'Stir all ingredients together and mix well.',
#    'Pour into a graham cracker crust.',
#    'Use top from crust to cover top of pie.',
#    'Chill overnight.',
#    'Makes 2 pies.'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': ['tangy'],
#   'ingredient_tags': ['c . pecans',
#    'can condensed milk',
#    'condensed milk',
#    'graham cracker crusts',
#    'large can crushed pineapple',
#    'large container cool whip',
#    'lemons',
#    'pecans',
#    'pineapple'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=794547',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.884653Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.884655Z'}},
#  {'title': 'Double Cherry Delight',
#   'slug': 'double-cherry-delight',
#   'ingredients': [{'name': '(17 oz.) can dark sweet pitted cherries',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 (17 oz.) can dark sweet pitted cherries'},
#    {'name': 'c . ginger ale',
#     'qty': 0.5,
#     'unit': None,
#     'raw': '1/2 c. ginger ale'},
#    {'name': '(6 oz.) pkg. jell-o cherry flavor gelatin',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 (6 oz.) pkg. Jell-O cherry flavor gelatin'},
#    {'name': 'c . boiling water',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2 c. boiling water'},
#    {'name': '. almond extract',
#     'qty': 0.125,
#     'unit': 'tsp',
#     'raw': '1/8 tsp. almond extract'},
#    {'name': 'c . miniature marshmallows',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. miniature marshmallows'}],
#   'steps': ['Drain cherries, measuring syrup.',
#    'Cut cherries in half.',
#    'Add ginger ale and enough water to syrup to make 1 1/2 cups.',
#    'Dissolve gelatin in boiling water.',
#    'Add measured liquid and almond extract. Chill until very thick.',
#    'Fold in marshmallows and the cherries. Spoon into 6-cup mold.',
#    'Chill until firm, at least 4 hours or overnight.',
#    'Unmold.',
#    'Makes about 5 1/3 cups.'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': ['sweet'],
#   'ingredient_tags': ['(17 oz.) can dark sweet pitted cherries',
#    '(6 oz.) pkg. jell-o cherry flavor gelatin',
#    '. almond extract',
#    'almond extract',
#    'boiling water',
#    'c . boiling water',
#    'c . ginger ale',
#    'c . miniature marshmallows',
#    'dark sweet pitted cherries',
#    'flavor gelatin',
#    'ginger ale',
#    'marshmallows'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=703381',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.884823Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.884825Z'}},
#  {'title': 'Buckeye Candy',
#   'slug': 'buckeye-candy',
#   'ingredients': [{'name': 'box powdered sugar',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 box powdered sugar'},
#    {'name': '. soft butter',
#     'qty': 8.0,
#     'unit': 'oz',
#     'raw': '8 oz. soft butter'},
#    {'name': '(8 oz.) peanut butter',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 (8 oz.) peanut butter'},
#    {'name': 'paraffin', 'qty': None, 'unit': None, 'raw': 'paraffin'},
#    {'name': '. chocolate chips',
#     'qty': 12.0,
#     'unit': 'oz',
#     'raw': '12 oz. chocolate chips'}],
#   'steps': ['Mix sugar, butter and peanut butter.',
#    'Roll into balls and place on cookie sheet.',
#    'Set in freezer for at least 30 minutes. Melt chocolate chips and paraffin in double boiler.',
#    'Using a toothpick, dip balls 3/4 of way into chocolate chip and paraffin mixture to make them look like buckeyes.'],
#   'tags': [],
#   'dietary_tags': ['vegetarian', 'gluten-free'],
#   'flavour_tags': ['sweet'],
#   'ingredient_tags': ['(8 oz.) peanut butter',
#    '. chocolate chips',
#    '. soft butter',
#    'box powdered sugar',
#    'butter',
#    'chocolate chips',
#    'paraffin',
#    'peanut butter',
#    'powdered sugar'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=886785',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.884955Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.884957Z'}},
#  {'title': 'Quick Barbecue Wings',
#   'slug': 'quick-barbecue-wings',
#   'ingredients': [{'name': 'chicken wings (as many as you need for dinner)',
#     'qty': None,
#     'unit': None,
#     'raw': 'chicken wings (as many as you need for dinner)'},
#    {'name': 'flour', 'qty': None, 'unit': None, 'raw': 'flour'},
#    {'name': 'barbecue sauce (your choice)',
#     'qty': None,
#     'unit': None,
#     'raw': 'barbecue sauce (your choice)'}],
#   'steps': ['Clean wings.',
#    'Flour and fry until done.',
#    'Place fried chicken wings in microwave bowl.',
#    'Stir in barbecue sauce.',
#    'Microwave on High (stir once) for 4 minutes.'],
#   'tags': [],
#   'dietary_tags': [],
#   'flavour_tags': [],
#   'ingredient_tags': ['barbecue sauce',
#    'barbecue sauce (your choice)',
#    'chicken',
#    'chicken wings (as many as you need for dinner)',
#    'flour'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=768311',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.885274Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.885277Z'}},
#  {'title': 'Taco Salad Chip Dip',
#   'slug': 'taco-salad-chip-dip',
#   'ingredients': [{'name': '. ortega taco sauce',
#     'qty': 8.0,
#     'unit': 'oz',
#     'raw': '8 oz. Ortega taco sauce'},
#    {'name': '. sour cream',
#     'qty': 8.0,
#     'unit': 'oz',
#     'raw': '8 oz. sour cream'},
#    {'name': '. cream cheese',
#     'qty': 8.0,
#     'unit': 'oz',
#     'raw': '8 oz. cream cheese'},
#    {'name': '. ground beef',
#     'qty': 1.0,
#     'unit': 'lb',
#     'raw': '1 lb. ground beef'},
#    {'name': 'pkg . taco seasoning',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 pkg. taco seasoning'},
#    {'name': 'shredded lettuce',
#     'qty': None,
#     'unit': None,
#     'raw': 'shredded lettuce'},
#    {'name': 'large diced tomato',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 large diced tomato'},
#    {'name': 'medium diced onion',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 medium diced onion'},
#    {'name': 'large diced green pepper',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 large diced green pepper'},
#    {'name': 'shredded colby or cheddar cheese',
#     'qty': None,
#     'unit': None,
#     'raw': 'shredded Colby or Cheddar cheese'}],
#   'steps': ['Mix taco sauce, sour cream and cream cheese.',
#    'Spread on pizza pan.',
#    'Brown meat.',
#    'Drain off fat and add taco seasoning.',
#    'Spread over cream mixture.',
#    'Layer with raw vegetables.',
#    'Top with cheese. Serve with chips.'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': [],
#   'ingredient_tags': ['. cream cheese',
#    '. ground beef',
#    '. ortega taco sauce',
#    '. sour cream',
#    'cheddar cheese',
#    'cream cheese',
#    'green pepper',
#    'ground beef',
#    'large diced green pepper',
#    'large diced tomato',
#    'medium diced onion',
#    'onion',
#    'pkg . taco seasoning',
#    'shredded colby or cheddar cheese',
#    'shredded lettuce',
#    'sour cream',
#    'taco sauce',
#    'taco seasoning',
#    'tomato'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=806409',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.885650Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.885654Z'}},
#  {'title': 'Pink Stuff(Frozen Dessert)  ',
#   'slug': 'pink-stuff-frozen-dessert',
#   'ingredients': [{'name': 'can pie filling (cherry or strawberry)',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 can pie filling (cherry or strawberry)'},
#    {'name': 'can crushed pineapple, drained',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 can crushed pineapple, drained'},
#    {'name': 'can sweetened condensed milk',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 can sweetened condensed milk'},
#    {'name': '(8 oz.) container thawed whipped topping',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 (8 oz.) container thawed whipped topping'},
#    {'name': '. lemon juice',
#     'qty': 2.0,
#     'unit': 'tbsp',
#     'raw': '2 Tbsp. lemon juice'}],
#   'steps': ['Mix all ingredients together.',
#    'Pour into a 9 x 13-inch pan. Freeze until firm.',
#    'Allow to set out approximately 15 minutes before serving.'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': ['tangy'],
#   'ingredient_tags': ['(8 oz.) container thawed whipped topping',
#    '. lemon juice',
#    'can crushed pineapple, drained',
#    'can pie filling (cherry or strawberry)',
#    'can sweetened condensed milk',
#    'condensed milk',
#    'lemon juice',
#    'pie filling',
#    'pineapple'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=982483',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.885808Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.885811Z'}},
#  {'title': 'Fresh Strawberry Pie',
#   'slug': 'fresh-strawberry-pie',
#   'ingredients': [{'name': 'baked pie shell',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 baked pie shell'},
#    {'name': 'qt . cleaned strawberries',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 qt. cleaned strawberries'},
#    {'name': 'c . water', 'qty': 1.5, 'unit': None, 'raw': '1 1/2 c. water'},
#    {'name': '. cornstarch',
#     'qty': 4.0,
#     'unit': 'tbsp',
#     'raw': '4 Tbsp. cornstarch'},
#    {'name': 'c . sugar', 'qty': 1.0, 'unit': None, 'raw': '1 c. sugar'},
#    {'name': '. salt', 'qty': 0.125, 'unit': 'tsp', 'raw': '1/8 tsp. salt'},
#    {'name': '. strawberry jello',
#     'qty': 4.0,
#     'unit': 'tbsp',
#     'raw': '4 Tbsp. strawberry jello'}],
#   'steps': ['Mix water, cornstarch, sugar and salt in saucepan.',
#    'Stir constantly and boil until thick and clear.',
#    'Remove from heat and stir in jello.',
#    'Set aside to cool.',
#    "But don't allow it to set. Layer strawberries in baked crust.",
#    'Pour cooled glaze over. Continue layering berries and glaze.',
#    'Refrigerate.',
#    'Serve with whipped cream.'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': ['sweet'],
#   'ingredient_tags': ['. cornstarch',
#    '. salt',
#    '. strawberry jello',
#    'baked pie shell',
#    'c . sugar',
#    'c . water',
#    'cleaned strawberries',
#    'cornstarch',
#    'qt . cleaned strawberries',
#    'salt',
#    'shell',
#    'strawberry jello',
#    'sugar',
#    'water'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=161321',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.886109Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.886112Z'}},
#  {'title': 'Easy German Chocolate Cake',
#   'slug': 'easy-german-chocolate-cake',
#   'ingredients': [{'name': 'pkg . chocolate fudge cake mix without pudding or 1 jiffy mix',
#     'qty': 0.5,
#     'unit': None,
#     'raw': '1/2 pkg. chocolate fudge cake mix without pudding or 1 Jiffy mix'},
#    {'name': 'pkg . white cake mix without pudding or 1 jiffy mix',
#     'qty': 0.5,
#     'unit': None,
#     'raw': '1/2 pkg. white cake mix without pudding or 1 Jiffy mix'},
#    {'name': 'c . wesson oil',
#     'qty': 0.25,
#     'unit': None,
#     'raw': '1/4 c. Wesson oil'}],
#   'steps': ['Mix according to directions and add oil.',
#    'Bake in 9 x 13-inch pan.'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': [],
#   'ingredient_tags': ['c . wesson oil',
#    'chocolate fudge cake',
#    'pkg . chocolate fudge cake mix without pudding or 1 jiffy mix',
#    'pkg . white cake mix without pudding or 1 jiffy mix',
#    'wesson oil',
#    'white cake'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=983179',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.886309Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.886311Z'}},
#  {'title': 'Broccoli Salad',
#   'slug': 'broccoli-salad',
#   'ingredients': [{'name': 'large head broccoli (about 1 1/2 lb.)',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 large head broccoli (about 1 1/2 lb.)'},
#    {'name': 'slices bacon, cooked and crumbled',
#     'qty': 10.0,
#     'unit': None,
#     'raw': '10 slices bacon, cooked and crumbled'},
#    {'name': 'green onions, sliced or 1/4 c. chopped red onion',
#     'qty': 5.0,
#     'unit': None,
#     'raw': '5 green onions, sliced or 1/4 c. chopped red onion'},
#    {'name': 'c . raisins', 'qty': 0.5, 'unit': None, 'raw': '1/2 c. raisins'},
#    {'name': 'c . mayonnaise',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. mayonnaise'},
#    {'name': '. vinegar', 'qty': 2.0, 'unit': 'tbsp', 'raw': '2 Tbsp. vinegar'},
#    {'name': 'c . sugar', 'qty': 0.25, 'unit': None, 'raw': '1/4 c. sugar'}],
#   'steps': ['Trim off large leaves of broccoli and remove the tough ends of lower stalks. Wash the broccoli thoroughly. Cut the florets and stems into bite-size pieces. Place in a large bowl. Add bacon, onions and raisins. Combine remaining ingredients, stirring well. Add dressing to broccoli mixture and toss gently. Cover and refrigerate 2 to 3 hours. Makes about 6 servings.'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': ['sweet', 'tangy'],
#   'ingredient_tags': ['. vinegar',
#    'bacon',
#    'broccoli',
#    'c . mayonnaise',
#    'c . raisins',
#    'c . sugar',
#    'green onions',
#    'green onions, sliced or 1/4 c. chopped red onion',
#    'large head broccoli (about 1 1/2 lb.)',
#    'mayonnaise',
#    'raisins',
#    'slices bacon, cooked and crumbled',
#    'sugar',
#    'vinegar'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=50992',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.886521Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.886526Z'}},
#  {'title': 'Strawberry Whatever',
#   'slug': 'strawberry-whatever',
#   'ingredients': [{'name': '. frozen strawberries in juice',
#     'qty': 1.0,
#     'unit': 'lb',
#     'raw': '1 lb. frozen strawberries in juice'},
#    {'name': 'small can crushed pineapple',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 small can crushed pineapple'},
#    {'name': 'ripe bananas', 'qty': 3.0, 'unit': None, 'raw': '3 ripe bananas'},
#    {'name': 'c . chopped pecans',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. chopped pecans'},
#    {'name': 'large pkg. strawberry jell-o',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 large pkg. strawberry Jell-O'},
#    {'name': 'c . boiling water',
#     'qty': 1.5,
#     'unit': None,
#     'raw': '1 1/2 c. boiling water'},
#    {'name': 'pt . sour cream',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 pt. sour cream'}],
#   'steps': ['Mix Jell-O in boiling water.',
#    'Add strawberries, pineapple, crushed bananas and nuts.',
#    'Spread 1/2 mixture in 13 x 6 1/2-inch pan.',
#    'Allow to gel in freezer 30 minutes.',
#    'Add layer of sour cream, then remaining mixture on top.',
#    'Gel and serve.'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': [],
#   'ingredient_tags': ['. frozen strawberries in juice',
#    'bananas',
#    'boiling water',
#    'c . boiling water',
#    'c . chopped pecans',
#    'frozen strawberries',
#    'large pkg. strawberry jell-o',
#    'pecans',
#    'pineapple',
#    'pt . sour cream',
#    'ripe bananas',
#    'small can crushed pineapple',
#    'sour cream',
#    'strawberry'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=718063',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.886743Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.886746Z'}},
#  {'title': 'Eggless Milkless Applesauce Cake',
#   'slug': 'eggless-milkless-applesauce-cake',
#   'ingredients': [{'name': 'c . sugar',
#     'qty': 0.75,
#     'unit': None,
#     'raw': '3/4 c. sugar'},
#    {'name': 'c . shortening',
#     'qty': 0.5,
#     'unit': None,
#     'raw': '1/2 c. shortening'},
#    {'name': 'c . applesauce',
#     'qty': 1.5,
#     'unit': None,
#     'raw': '1 1/2 c. applesauce'},
#    {'name': 'level tsp. soda',
#     'qty': 3.0,
#     'unit': None,
#     'raw': '3 level tsp. soda'},
#    {'name': '. each: cinnamon, cloves and nutmeg',
#     'qty': 1.0,
#     'unit': 'tsp',
#     'raw': '1 tsp. each: cinnamon, cloves and nutmeg'},
#    {'name': 'c . sifted flour',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2 c. sifted flour'},
#    {'name': 'c . raisins', 'qty': 1.0, 'unit': None, 'raw': '1 c. raisins'},
#    {'name': 'c . nuts', 'qty': 1.0, 'unit': None, 'raw': '1 c. nuts'}],
#   'steps': ['Mix Crisco with applesauce, nuts and raisins.',
#    'Sift dry ingredients and add.',
#    'Mix well.',
#    'Put in a greased and floured loaf pan or tube pan.',
#    'Bake in loaf pan at 350° to 375° for 45 to 60 minutes, layer pan at 375° for 20 minutes or tube pan at 325° for 1 hour.'],
#   'tags': [],
#   'dietary_tags': ['vegan'],
#   'flavour_tags': ['sweet'],
#   'ingredient_tags': ['. each: cinnamon, cloves and nutmeg',
#    'applesauce',
#    'c . applesauce',
#    'c . nuts',
#    'c . raisins',
#    'c . shortening',
#    'c . sifted flour',
#    'c . sugar',
#    'cinnamon',
#    'flour',
#    'level tsp. soda',
#    'nuts',
#    'raisins',
#    'shortening',
#    'soda',
#    'sugar'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=343158',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.887174Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.887178Z'}},
#  {'title': "Grandma Hanrath'S Banana Breadfort Collins, Colorado  ",
#   'slug': 'grandma-hanrath-s-banana-breadfort-collins-colorado',
#   'ingredients': [{'name': 'c . sugar',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. sugar'},
#    {'name': 'c . shortening',
#     'qty': 0.5,
#     'unit': None,
#     'raw': '1/2 c. shortening'},
#    {'name': 'eggs (add one at a time)',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2 eggs (add one at a time)'},
#    {'name': '. salt', 'qty': 1.0, 'unit': 'tsp', 'raw': '1 tsp. salt'},
#    {'name': '. soda', 'qty': 2.0, 'unit': 'tsp', 'raw': '2 tsp. soda'},
#    {'name': 'c . flour', 'qty': 2.0, 'unit': None, 'raw': '2 c. flour'},
#    {'name': 'c . nuts', 'qty': 0.25, 'unit': None, 'raw': '1/4 c. nuts'},
#    {'name': 'over -ripe bananas (chopped)',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2 over-ripe bananas (chopped)'}],
#   'steps': ['Cream sugar and shortening.',
#    'Add eggs, salt and soda, then bananas and flour.',
#    'Add nuts.',
#    'Mix well.',
#    'Bake in loaf pan at 350° for 1 hour.'],
#   'tags': [],
#   'dietary_tags': ['vegan'],
#   'flavour_tags': ['sweet'],
#   'ingredient_tags': ['. salt',
#    '. soda',
#    'bananas',
#    'c . flour',
#    'c . nuts',
#    'c . shortening',
#    'c . sugar',
#    'eggs',
#    'eggs (add one at a time)',
#    'flour',
#    'nuts',
#    'over -ripe bananas (chopped)',
#    'salt',
#    'shortening',
#    'soda',
#    'sugar'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=1072247',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.887372Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.887375Z'}},
#  {'title': 'Chocolate Frango Mints',
#   'slug': 'chocolate-frango-mints',
#   'ingredients': [{'name': "pkg . devil's food cake mix",
#     'qty': 1.0,
#     'unit': None,
#     'raw': "1 pkg. devil's food cake mix"},
#    {'name': 'pkg . chocolate fudge pudding mix (instant)',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 pkg. chocolate fudge pudding mix (instant)'},
#    {'name': '. sour cream',
#     'qty': 8.0,
#     'unit': 'oz',
#     'raw': '8 oz. sour cream'},
#    {'name': 'c . water', 'qty': 0.75, 'unit': None, 'raw': '3/4 c. water'},
#    {'name': 'c . wesson oil',
#     'qty': 0.5,
#     'unit': None,
#     'raw': '1/2 c. Wesson oil'},
#    {'name': 'eggs', 'qty': 4.0, 'unit': None, 'raw': '4 eggs'},
#    {'name': '. chopped frango mints',
#     'qty': 6.0,
#     'unit': 'oz',
#     'raw': '6 oz. chopped Frango mints'}],
#   'steps': ['Mix ingredients together for 5 minutes.',
#    'Scrape bowl often. Last fold in chocolate chip mints.',
#    'Bake at 350° for 35 to 40 minutes or until done (cake mix directions).'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': ['herby'],
#   'ingredient_tags': ['. chopped frango mints',
#    '. sour cream',
#    'c . water',
#    'c . wesson oil',
#    'cake mix',
#    'chocolate fudge pudding',
#    'eggs',
#    'frango',
#    'pkg . chocolate fudge pudding mix (instant)',
#    "pkg . devil's food cake mix",
#    'sour cream',
#    'water',
#    'wesson oil'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=958474',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.887532Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.887534Z'}},
#  {'title': 'Cuddy Farms Marinated Turkey',
#   'slug': 'cuddy-farms-marinated-turkey',
#   'ingredients': [{'name': 'c . 7-up or sprite',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2 c. 7-Up or Sprite'},
#    {'name': 'c . vegetable oil',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. vegetable oil'},
#    {'name': 'c . kikkoman soy sauce',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. Kikkoman soy sauce'},
#    {'name': 'garlic salt', 'qty': None, 'unit': None, 'raw': 'garlic salt'}],
#   'steps': ['Buy whole turkey breast; remove all skin and bones. Cut into pieces about the size of your hand. Pour marinade over turkey and refrigerate for at least 8 hours (up to 48 hours). The longer it marinates, the less cooking time it takes.'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': ['umami'],
#   'ingredient_tags': ['c . 7-up or sprite',
#    'c . kikkoman soy sauce',
#    'c . vegetable oil',
#    'garlic',
#    'garlic salt',
#    'soy sauce',
#    'vegetable oil'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=9449',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.887650Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.887652Z'}},
#  {'title': 'Spaghetti Sauce To Can',
#   'slug': 'spaghetti-sauce-to-can',
#   'ingredients': [{'name': 'bushel tomatoes',
#     'qty': 0.5,
#     'unit': None,
#     'raw': '1/2 bushel tomatoes'},
#    {'name': 'c . oil', 'qty': 1.0, 'unit': None, 'raw': '1 c. oil'},
#    {'name': 'c . minced garlic',
#     'qty': 0.25,
#     'unit': None,
#     'raw': '1/4 c. minced garlic'},
#    {'name': 'cans tomato paste',
#     'qty': 6.0,
#     'unit': None,
#     'raw': '6 cans tomato paste'},
#    {'name': 'peppers (2 sweet and 1 hot)',
#     'qty': 3.0,
#     'unit': None,
#     'raw': '3 peppers (2 sweet and 1 hot)'},
#    {'name': 'c . sugar', 'qty': 1.5, 'unit': None, 'raw': '1 1/2 c. sugar'},
#    {'name': 'c . salt', 'qty': 0.5, 'unit': None, 'raw': '1/2 c. salt'},
#    {'name': '. sweet basil',
#     'qty': 1.0,
#     'unit': 'tbsp',
#     'raw': '1 Tbsp. sweet basil'},
#    {'name': '. oregano', 'qty': 2.0, 'unit': 'tbsp', 'raw': '2 Tbsp. oregano'},
#    {'name': '. italian seasoning',
#     'qty': 1.0,
#     'unit': 'tsp',
#     'raw': '1 tsp. Italian seasoning'}],
#   'steps': ['Cook ground or chopped peppers and onions in oil for 1/2 hour. Cook tomatoes and garlic as for juice.',
#    'Put through the mill.',
#    '(I use a food processor and do my tomatoes uncooked.',
#    'I then add the garlic right to the juice.)',
#    'Add peppers and onions to juice and remainder of ingredients.',
#    'Cook approximately 1 hour.',
#    'Put in jars and seal.',
#    'Yields 7 quarts.'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': ['herby', 'sweet'],
#   'ingredient_tags': ['. italian seasoning',
#    '. oregano',
#    '. sweet basil',
#    'bushel tomatoes',
#    'c . minced garlic',
#    'c . oil',
#    'c . salt',
#    'c . sugar',
#    'cans tomato paste',
#    'garlic',
#    'italian seasoning',
#    'oil',
#    'oregano',
#    'peppers',
#    'peppers (2 sweet and 1 hot)',
#    'salt',
#    'sugar',
#    'sweet basil',
#    'tomato paste',
#    'tomatoes'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=1059279',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.887957Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.887961Z'}},
#  {'title': 'Prize-Winning Meat Loaf',
#   'slug': 'prize-winning-meat-loaf',
#   'ingredients': [{'name': '. ground beef',
#     'qty': 1.5,
#     'unit': 'lb',
#     'raw': '1 1/2 lb. ground beef'},
#    {'name': 'c . tomato juice',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. tomato juice'},
#    {'name': 'c . oats (uncooked)',
#     'qty': 0.75,
#     'unit': None,
#     'raw': '3/4 c. oats (uncooked)'},
#    {'name': 'egg , beaten', 'qty': 1.0, 'unit': None, 'raw': '1 egg, beaten'},
#    {'name': 'c . chopped onion',
#     'qty': 0.25,
#     'unit': None,
#     'raw': '1/4 c. chopped onion'},
#    {'name': '. pepper', 'qty': 0.25, 'unit': 'tsp', 'raw': '1/4 tsp. pepper'},
#    {'name': '. salt', 'qty': 1.5, 'unit': 'tsp', 'raw': '1 1/2 tsp. salt'}],
#   'steps': ['Mix well.',
#    'Press firmly into an 8 1/2 x 4 1/2 x 2 1/2-inch loaf pan.',
#    'Bake in preheated moderate oven.',
#    'Bake at 350° for 1 hour.',
#    'Let stand 5 minutes before slicing.',
#    'Makes 8 servings.'],
#   'tags': [],
#   'dietary_tags': ['vegetarian', 'gluten-free'],
#   'flavour_tags': [],
#   'ingredient_tags': ['. ground beef',
#    '. pepper',
#    '. salt',
#    'c . chopped onion',
#    'c . oats (uncooked)',
#    'c . tomato juice',
#    'egg',
#    'egg , beaten',
#    'ground beef',
#    'oats',
#    'onion',
#    'pepper',
#    'salt',
#    'tomato juice'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=923674',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.888171Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.888174Z'}},
#  {'title': 'Smothered Round Steak(Servings: 4)  ',
#   'slug': 'smothered-round-steak-servings-4',
#   'ingredients': [{'name': '. round steak',
#     'qty': 2.0,
#     'unit': 'lb',
#     'raw': '2 lb. round steak'},
#    {'name': '. ground black pepper',
#     'qty': 0.5,
#     'unit': 'tsp',
#     'raw': '1/2 tsp. ground black pepper'},
#    {'name': '. ground white pepper',
#     'qty': 1.0,
#     'unit': 'tsp',
#     'raw': '1 tsp. ground white pepper'},
#    {'name': 'c . vegetable oil',
#     'qty': 0.5,
#     'unit': None,
#     'raw': '1/2 c. vegetable oil'},
#    {'name': 'bell peppers, chopped',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2 bell peppers, chopped'},
#    {'name': 'c . beef stock or water',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. beef stock or water'},
#    {'name': '. salt', 'qty': 2.0, 'unit': 'tsp', 'raw': '2 tsp. salt'},
#    {'name': '. ground red pepper',
#     'qty': 1.0,
#     'unit': 'tsp',
#     'raw': '1 tsp. ground red pepper'},
#    {'name': 'all-purpose flour (dredging)',
#     'qty': None,
#     'unit': None,
#     'raw': 'all-purpose flour (dredging)'},
#    {'name': 'medium onions, chopped',
#     'qty': 3.0,
#     'unit': None,
#     'raw': '3 medium onions, chopped'},
#    {'name': 'celery rib, chopped',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 celery rib, chopped'}],
#   'steps': ['Alex Patout says, "Smothering is a multipurpose Cajun technique that works wonders with everything from game to snap beans.',
# ...
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=449577',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.986116Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.986117Z'}},
#  {'title': 'Favorite Chocolate Cake',
#   'slug': 'favorite-chocolate-cake',
#   'ingredients': [{'name': 'c . flour',
#     'qty': 1.75,
#     'unit': None,
#     'raw': '1 3/4 c. flour'},
#    {'name': 'eggs', 'qty': 2.0, 'unit': None, 'raw': '2 eggs'},
#    {'name': '. baking powder',
#     'qty': 1.0,
#     'unit': 'tsp',
#     'raw': '1 tsp. baking powder'},
#    {'name': '. red food coloring',
#     'qty': 1.0,
#     'unit': 'tsp',
#     'raw': '1 tsp. red food coloring'},
#    {'name': '. salt', 'qty': 0.5, 'unit': 'tsp', 'raw': '1/2 tsp. salt'},
#    {'name': '. soda', 'qty': 0.5, 'unit': 'tsp', 'raw': '1/2 tsp. soda'},
#    {'name': 'c . sugar', 'qty': 1.5, 'unit': None, 'raw': '1 1/2 c. sugar'},
#    {'name': '. cocoa', 'qty': 7.0, 'unit': 'tbsp', 'raw': '7 Tbsp. cocoa'},
#    {'name': 'c . shortening',
#     'qty': 0.5,
#     'unit': None,
#     'raw': '1/2 c. shortening'},
#    {'name': 'c . buttermilk',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. buttermilk'}],
#   'steps': ['Sift all dry ingredients in a large mixing bowl.',
#    'Stir.',
#    'Add the rest and beat with electric mixer for 2 minutes.',
#    'Pour into greased and floured pans (2).',
#    'I use small tube pan.',
#    'Bake at 350° for 30 minutes.',
#    'Tube pan takes 40 minutes.'],
#   'tags': [],
#   'dietary_tags': ['vegan'],
#   'flavour_tags': ['sweet'],
#   'ingredient_tags': ['. baking powder',
#    '. cocoa',
#    '. red food coloring',
#    '. salt',
#    '. soda',
#    'baking powder',
#    'buttermilk',
#    'c . buttermilk',
#    'c . flour',
#    'c . shortening',
#    'c . sugar',
#    'cocoa',
#    'eggs',
#    'flour',
#    'red food coloring',
#    'salt',
#    'shortening',
#    'soda',
#    'sugar'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=684926',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.986213Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.986213Z'}},
#  {'title': 'Blue Muffins',
#   'slug': 'blue-muffins',
#   'ingredients': [{'name': 'egg', 'qty': 1.0, 'unit': None, 'raw': '1 egg'},
#    {'name': 'c . milk', 'qty': 1.0, 'unit': None, 'raw': '1 c. milk'},
#    {'name': '. melted shortening',
#     'qty': 2.0,
#     'unit': 'tbsp',
#     'raw': '2 Tbsp. melted shortening'},
#    {'name': '. sugar', 'qty': 2.0, 'unit': 'tbsp', 'raw': '2 Tbsp. sugar'},
#    {'name': 'c . flour', 'qty': 2.0, 'unit': None, 'raw': '2 c. flour'},
#    {'name': 'c . blueberries',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2 c. blueberries'}],
#   'steps': ['Mix thoroughly.', 'Pour into muffin pans and bake at 350°.'],
#   'tags': [],
#   'dietary_tags': ['vegetarian'],
#   'flavour_tags': ['sweet'],
#   'ingredient_tags': ['. melted shortening',
#    '. sugar',
#    'blueberries',
#    'c . blueberries',
#    'c . flour',
#    'c . milk',
#    'egg',
#    'flour',
#    'milk',
#    'shortening',
#    'sugar'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=533822',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.986268Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.986269Z'}},
#  {'title': 'Devils Chicken(Pollo Alla Diavola)  ',
#   'slug': 'devils-chicken-pollo-alla-diavola',
#   'ingredients': [{'name': '(3 to 4 lb.) chicken',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 (3 to 4 lb.) chicken'},
#    {'name': 'c . olive oil',
#     'qty': 0.5,
#     'unit': None,
#     'raw': '1/2 c. olive oil'},
#    {'name': '. hot pepper sauce (tabasco sauce) or to taste',
#     'qty': 2.0,
#     'unit': 'tbsp',
#     'raw': '2 Tbsp. hot pepper sauce (Tabasco sauce) or to taste'},
#    {'name': 'juice of 2 lemons',
#     'qty': None,
#     'unit': None,
#     'raw': 'juice of 2 lemons'},
#    {'name': 'ground pepper to taste',
#     'qty': None,
#     'unit': None,
#     'raw': 'ground pepper to taste'},
#    {'name': '. salt', 'qty': 1.0, 'unit': 'tsp', 'raw': '1 tsp. salt'}],
#   'steps': ['Using poultry shears, cut the bird open by cutting down the backbone.',
#    'Flatten a bit by pounding with your hand so that the chicken is "butterflied".',
#    'Mix the remaining ingredients in a large bowl; marinate the bird for 2 hours.'],
#   'tags': [],
#   'dietary_tags': ['gluten-free'],
#   'flavour_tags': ['tangy'],
#   'ingredient_tags': ['(3 to 4 lb.) chicken',
#    '. hot pepper sauce (tabasco sauce) or to taste',
#    '. salt',
#    'c . olive oil',
#    'chicken',
#    'ground pepper',
#    'ground pepper to taste',
#    'hot pepper',
#    'juice of 2 lemons',
#    'lemons',
#    'olive oil',
#    'salt'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=680725',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.986336Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.986337Z'}},
#  {'title': 'Friendship Tea',
#   'slug': 'friendship-tea',
#   'ingredients': [{'name': 'c . instant tea',
#     'qty': 0.5,
#     'unit': None,
#     'raw': '1/2 c. instant tea'},
#    {'name': 'c . tang', 'qty': 2.0, 'unit': None, 'raw': '2 c. Tang'},
#    {'name': "pkg . wyler's lemonade mix (3 oz.)",
#     'qty': 1.0,
#     'unit': None,
#     'raw': "1 pkg. Wyler's lemonade mix (3 oz.)"},
#    {'name': '. cinnamon', 'qty': 1.0, 'unit': 'tsp', 'raw': '1 tsp. cinnamon'},
#    {'name': 'c . sugar', 'qty': 2.0, 'unit': None, 'raw': '2 c. sugar'}],
#   'steps': ['Mix 3 heaping tablespoonfuls per cup of hot water.'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': ['sweet', 'tangy'],
#   'ingredient_tags': ['. cinnamon',
#    'c . instant tea',
#    'c . sugar',
#    'c . tang',
#    'cinnamon',
#    'instant tea',
#    "pkg . wyler's lemonade mix (3 oz.)",
#    'sugar'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=1025828',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.986385Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.986386Z'}},
#  {'title': 'Heath Bar Pie',
#   'slug': 'heath-bar-pie',
#   'ingredients': [{'name': 'heath bars, chopped fine',
#     'qty': 3.0,
#     'unit': None,
#     'raw': '3 Heath bars, chopped fine'},
#    {'name': 'medium container whipping topping',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 medium container whipping topping'},
#    {'name': 'graham cracker pie crust',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 graham cracker pie crust'},
#    {'name': 'chocolate curls or chopped nuts',
#     'qty': None,
#     'unit': None,
#     'raw': 'chocolate curls or chopped nuts'}],
#   'steps': ['Mix chopped Heath bars with whipped topping and pour into crust.',
#    'Top with chocolate curls or chopped nuts.',
#    'Refrigerate.'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': [],
#   'ingredient_tags': ['chocolate curls',
#    'chocolate curls or chopped nuts',
#    'graham cracker pie crust',
#    'heath bars, chopped fine',
#    'medium container whipping topping'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=976718',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.986440Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.986441Z'}},
#  {'title': 'Victorian Baked French Toast',
#   'slug': 'victorian-baked-french-toast',
#   'ingredients': [{'name': 'c . brown sugar',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. brown sugar'},
#    {'name': 'c . butter',
#     'qty': 0.3333333333333333,
#     'unit': None,
#     'raw': '1/3 c. butter'},
#    {'name': '. light corn syrup',
#     'qty': 2.0,
#     'unit': 'tbsp',
#     'raw': '2 Tbsp. light corn syrup'},
#    {'name': 'slices french bread (1-inch thick)',
#     'qty': 8.0,
#     'unit': None,
#     'raw': '8 slices French bread (1-inch thick)'},
#    {'name': 'eggs', 'qty': 5.0, 'unit': None, 'raw': '5 eggs'},
#    {'name': 'c . milk', 'qty': 1.5, 'unit': None, 'raw': '1 1/2 c. milk'},
#    {'name': '. cinnamon',
#     'qty': 1.0,
#     'unit': 'tsp',
#     'raw': '1 tsp. cinnamon'}],
#   'steps': ['Cook brown sugar, butter and corn syrup in small saucepan until butter melts.',
#    'Pour into 9 x 13-inch pan.',
#    'Layer bread in pan, squeezing together to fit.',
#    'Mix eggs, milk and cinnamon. Pour over bread (you can cover and refrigerate overnight).',
#    'Bake at 350° for 30 minutes or until center is done and lightly browned.'],
#   'tags': [],
#   'dietary_tags': ['vegetarian', 'gluten-free'],
#   'flavour_tags': ['sweet'],
#   'ingredient_tags': ['. cinnamon',
#    '. light corn syrup',
#    'bread',
#    'brown sugar',
#    'butter',
#    'c . brown sugar',
#    'c . butter',
#    'c . milk',
#    'cinnamon',
#    'eggs',
#    'light corn syrup',
#    'milk',
#    'slices french bread (1-inch thick)'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=908190',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.986526Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.986527Z'}},
#  {'title': 'Quick Swedish Meatballs',
#   'slug': 'quick-swedish-meatballs',
#   'ingredients': [{'name': '. ground beef',
#     'qty': 1.0,
#     'unit': 'lb',
#     'raw': '1 lb. ground beef'},
#    {'name': 'c . soft bread crumbs',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 c. soft bread crumbs'},
#    {'name': '(3 oz.) pkg. cream cheese',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 (3 oz.) pkg. cream cheese'},
#    {'name': 'c . dry onion soup mix',
#     'qty': 0.25,
#     'unit': None,
#     'raw': '1/4 c. dry onion soup mix'},
#    {'name': '. salt', 'qty': 0.25, 'unit': 'tsp', 'raw': '1/4 tsp. salt'},
#    {'name': '. nutmeg', 'qty': 0.25, 'unit': 'tsp', 'raw': '1/4 tsp. nutmeg'},
#    {'name': 'c . milk', 'qty': 1.5, 'unit': None, 'raw': '1 1/2 c. milk'},
#    {'name': 'pkg . stroganoff sauce mix',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 pkg. stroganoff sauce mix'}],
#   'steps': ['Combine meat, bread crumbs, cheese, soup mix, seasonings and 1/4 cup milk; mix thoroughly (with hands).',
#    'Form into small balls. Brown lightly; remove to a baking dish.',
#    'Drain excess grease, leaving small amount in skillet.',
#    'Blend in sauce mix and remaining milk (add more or less milk for desired thickness).',
#    'Cook until thick and bubbly.',
#    'Pour over meat balls.',
#    'Bake in a 350° oven for 30 to 45 minutes.'],
#   'tags': [],
#   'dietary_tags': ['vegetarian', 'gluten-free'],
#   'flavour_tags': [],
#   'ingredient_tags': ['(3 oz.) pkg. cream cheese',
#    '. ground beef',
#    '. nutmeg',
#    '. salt',
#    'bread crumbs',
#    'c . dry onion soup mix',
#    'c . milk',
#    'c . soft bread crumbs',
#    'cream cheese',
#    'ground beef',
#    'milk',
#    'nutmeg',
#    'onion soup',
#    'pkg . stroganoff sauce mix',
#    'salt',
#    'stroganoff sauce mix'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=850050',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.986631Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.986632Z'}},
#  {'title': 'Irish Stew(Microwave)  ',
#   'slug': 'irish-stew-microwave',
#   'ingredients': [{'name': '. lamb, cut in 1-inch cubes',
#     'qty': 2.0,
#     'unit': 'lb',
#     'raw': '2 lb. lamb, cut in 1-inch cubes'},
#    {'name': 'c . water', 'qty': 2.0, 'unit': None, 'raw': '2 c. water'},
#    {'name': 'envelope onion soup mix',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 envelope onion soup mix'},
#    {'name': 'bay leaf', 'qty': 1.0, 'unit': None, 'raw': '1 bay leaf'},
#    {'name': 'medium carrots, sliced thin',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2 medium carrots, sliced thin'},
#    {'name': 'baked potatoes',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2 baked potatoes'},
#    {'name': 'c . flour', 'qty': 0.25, 'unit': None, 'raw': '1/4 c. flour'}],
#   'steps': ['In 4-quart casserole, combine lamb, 1 1/4 cups water, soup mix and bay leaf.',
#    'Heat, covered, 7 to 8 minutes on High.',
#    'Continue cooking on power level 3 for 35 to 40 minutes.',
#    'Stir occasionally. Add carrots, heat on level 3 for 15 minutes until ingredients are done.',
#    'Stir once.',
#    'Peel and cube potatoes and add to stew.',
#    'Blend flour and remaining water.',
#    'Heat 5 minutes on High, or until thickened, stirring twice.',
#    'Serves 6.'],
#   'tags': [],
#   'dietary_tags': [],
#   'flavour_tags': [],
#   'ingredient_tags': ['. lamb, cut in 1-inch cubes',
#    'baked potatoes',
#    'bay leaf',
#    'c . flour',
#    'c . water',
#    'carrots',
#    'envelope onion soup mix',
#    'flour',
#    'lamb',
#    'medium carrots, sliced thin',
#    'onion soup',
#    'potatoes',
#    'water'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=1017368',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.986745Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.986746Z'}},
#  {'title': 'Peach Salad',
#   'slug': 'peach-salad',
#   'ingredients': [{'name': '-3 oz boxes peach jello',
#     'qty': 2.0,
#     'unit': None,
#     'raw': '2-3 oz boxes Peach Jello'},
#    {'name': 'large jar peach baby food',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 large jar Peach Baby food'},
#    {'name': 'can condensed milk',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 can Condensed Milk'},
#    {'name': '-8 oz pkg. cream cheese, softened',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1-8 oz pkg. cream cheese, softened'},
#    {'name': 'c . hot water',
#     'qty': 0.6666666666666666,
#     'unit': None,
#     'raw': '2/3 c. hot water'},
#    {'name': 'c . sugar', 'qty': 0.5, 'unit': None, 'raw': '1/2 c. sugar'},
#    {'name': 'large can crushed pineapple, not drained',
#     'qty': 1.0,
#     'unit': None,
#     'raw': '1 large can crushed pineapple, not drained'}],
#   'steps': ['Mix jello with hot water and sugar. Allow to come to a boil. Take off stove and add peaches and pineapple.'],
#   'tags': [],
#   'dietary_tags': ['vegan', 'gluten-free'],
#   'flavour_tags': ['sweet'],
#   'ingredient_tags': ['-3 oz boxes peach jello',
#    '-8 oz pkg. cream cheese, softened',
#    'c . hot water',
#    'c . sugar',
#    'can condensed milk',
#    'condensed milk',
#    'cream cheese',
#    'food',
#    'hot water',
#    'jello',
#    'large can crushed pineapple, not drained',
#    'large jar peach baby food',
#    'pineapple',
#    'sugar'],
#   'cuisine': None,
#   'course': None,
#   'servings': None,
#   'times': {'prep_min': None, 'cook_min': None, 'total_min': None},
#   'nutrition': {},
#   'rating': {'value': None, 'count': None},
#   'images': [],
#   'source_url': 'www.cookbooks.com/Recipe-Details.aspx?id=65771',
#   'author': 'Gathered',
#   'created_at': {'$date': '2025-10-31T07:15:35.986814Z'},
#   'updated_at': {'$date': '2025-10-31T07:15:35.986815Z'}},
#  ...]

# %%
pd.DataFrame([{
    "title": d["title"][:40],
    "dietary": ",".join(d["dietary_tags"]),
    "flavour": ",".join(d["flavour_tags"]),
    "n_ings": len(d["ingredients"])
} for d in out_docs[:10]])
# Out:
#                       title                 dietary flavour  n_ings
# 0       No-Bake Nut Cookies  vegetarian,gluten-free   sweet       6
# 1     Jewell Ball'S Chicken             gluten-free   umami       4
# 2               Creamy Corn  vegetarian,gluten-free               6
# 3             Chicken Funny             gluten-free   umami       5
# 4      Reeses Cups(Candy)    vegetarian,gluten-free   sweet       5
# 5  Cheeseburger Potato Soup  vegetarian,gluten-free              10
# 6       Rhubarb Coffee Cake              vegetarian   sweet      10
# 7            Scalloped Corn  vegetarian,gluten-free               6
# 8      Nolan'S Pepper Steak       vegan,gluten-free               7
# 9           Millionaire Pie       vegan,gluten-free   tangy       6

# %% [markdown]
# ## mongo ready JSONL

# %%
from pathlib import Path
import json, os

OUT_JSONL = Path("init") / "03_recipe_csv_sample.jsonl"  
OUT_JSONL.parent.mkdir(parents=True, exist_ok=True)

with open(OUT_JSONL, "w", encoding="utf-8") as f:
    for d in out_docs:
        f.write(json.dumps(d, ensure_ascii=False) + "\n")

print("Wrote:", OUT_JSONL, "records:", len(out_docs))
# Out:
# Wrote: init/03_recipe_csv_sample.jsonl records: 2231142

# %% [markdown]
# ### import into mongo -> rebuild_mongo.sh uses 03_recipe_csv_sample.jsonl
